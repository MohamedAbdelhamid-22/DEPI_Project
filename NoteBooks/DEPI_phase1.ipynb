# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('final_weather.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5907 entries, 0 to 5906
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               5907 non-null   object
#  1   avg_wind_speed     5907 non-null   float64
#  2   precipitation      5907 non-null   float64
#  3   max_temp           5907 non-null   float64
#  4   min_temp           5907 non-null   float64
#  5   week_year          5907 non-null   int64
#  6   day_of_week        5907 non-null   object
#  7   week_day_num       5907 non-null   int64
#  8   month              5907 non-null   int64
#  9   year               5907 non-null   int64
#  10  day_number         5907 non-null   int64
#  11  event_1_name       5907 non-null   object
#  12  event_1_type       5907 non-null   object
#  13  event_2_name       5907 non-null   object
#  14  event_2_type       5907 non-null   object
#  15  snap_state_CA      5907 non-null   float64
# ...

# %%
df.describe()
# Out:
#        avg_wind_speed  precipitation     max_temp    min_temp     week_year  \
# count     5907.000000    5907.000000  5907.000000  5907.00000   5907.000000
# mean         7.243178       0.081554    70.548671    53.04537  11347.086338
# std          3.564705       0.320863    18.303194    16.89682    155.250749
# min          0.000000       0.000000    -4.000000   -14.00000  11101.000000
# 25%          4.700000       0.000000    62.000000    44.00000  11219.000000
# 50%          6.260000       0.000000    74.000000    56.00000  11337.000000
# 75%          9.170000       0.000000    83.000000    65.00000  11502.000000
# max         24.830000       6.050000   106.000000    82.00000  11621.000000
#
#        week_day_num        month         year   day_number  snap_state_CA  \
# count   5907.000000  5907.000000  5907.000000  5907.000000    5907.000000
# mean       3.997461     6.325546  2013.288471   985.000000       0.110039
# ...

# %%
df.head()
# Out:
#          date  avg_wind_speed  precipitation  max_temp  min_temp  week_year  \
# 0  2011-01-29            2.01           0.00      62.0      46.0      11101
# 1  2011-01-30            5.82           0.23      60.0      52.0      11101
# 2  2011-01-31            1.79           0.00      63.0      44.0      11101
# 3  2011-02-01            2.01           0.00      62.0      46.0      11101
# 4  2011-02-02            4.70           0.00      65.0      42.0      11101
#
#   day_of_week  week_day_num  month  year  day_number event_1_name  \
# 0    Saturday             1      1  2011           1     No Event
# 1      Sunday             2      1  2011           2     No Event
# 2      Monday             3      1  2011           3     No Event
# 3     Tuesday             4      2  2011           4     No Event
# 4   Wednesday             5      2  2011           5     No Event
#
#   event_1_type event_2_name event_2_type  snap_state_CA State  snap_state_WI  \
# ...

# %%
df.tail()
# Out:
#             date  avg_wind_speed  precipitation  max_temp  min_temp  \
# 5902  2016-06-15            8.05           0.00      95.0      79.0
# 5903  2016-06-16            6.71           0.00      95.0      78.0
# 5904  2016-06-17            5.37           0.00      96.0      77.0
# 5905  2016-06-18            4.92           0.45      97.0      74.0
# 5906  2016-06-19            4.03           0.44      91.0      75.0
#
#       week_year day_of_week  week_day_num  month  year  day_number  \
# 5902      11620   Wednesday             5      6  2016        1965
# 5903      11620    Thursday             6      6  2016        1966
# 5904      11620      Friday             7      6  2016        1967
# 5905      11621    Saturday             1      6  2016        1968
# 5906      11621      Sunday             2      6  2016        1969
#
#       event_1_name event_1_type  event_2_name event_2_type  snap_state_CA  \
# 5902      No Event     No Event      No Event     No Event            0.0
# ...

# %%
# california's part
df.loc[0:1968,]
# Out:
#             date  avg_wind_speed  precipitation  max_temp  min_temp  \
# 0     2011-01-29            2.01           0.00      62.0      46.0
# 1     2011-01-30            5.82           0.23      60.0      52.0
# 2     2011-01-31            1.79           0.00      63.0      44.0
# 3     2011-02-01            2.01           0.00      62.0      46.0
# 4     2011-02-02            4.70           0.00      65.0      42.0
# ...          ...             ...            ...       ...       ...
# 1964  2016-06-15            5.82           0.00      72.0      61.0
# 1965  2016-06-16            6.04           0.00      79.0      57.0
# 1966  2016-06-17            6.04           0.00      87.0      60.0
# 1967  2016-06-18            6.93           0.00      92.0      63.0
# 1968  2016-06-19            8.28           0.00     100.0      67.0
#
#       week_year day_of_week  week_day_num  month  year  day_number  \
# 0         11101    Saturday             1      1  2011           1
# ...

# %%
# Wisconsin's part
df.loc[1969:3937,]
# Out:
#             date  avg_wind_speed  precipitation  max_temp  min_temp  \
# 1969  2011-01-29            7.16           0.00      34.0      27.0
# 1970  2011-01-30           10.74           0.00      28.0      23.0
# 1971  2011-01-31           17.00           0.14      26.0      20.0
# 1972  2011-02-01           23.94           0.29      24.0      19.0
# 1973  2011-02-02           19.24           0.60      24.0       9.0
# ...          ...             ...            ...       ...       ...
# 3933  2016-06-15           10.51           1.03      79.0      65.0
# 3934  2016-06-16           10.96           0.00      72.0      61.0
# 3935  2016-06-17            5.14           0.00      79.0      60.0
# 3936  2016-06-18            4.92           0.00      82.0      58.0
# 3937  2016-06-19            9.40           0.00      89.0      65.0
#
#       week_year day_of_week  week_day_num  month  year  day_number  \
# 1969      11101    Saturday             1      1  2011           1
# ...

# %%
# Texas's part
df.loc[3937:,]
# Out:
#             date  avg_wind_speed  precipitation  max_temp  min_temp  \
# 3937  2016-06-19            9.40           0.00      89.0      65.0
# 3938  2011-01-29            7.83           0.00      74.0      52.0
# 3939  2011-01-30            6.93           0.10      71.0      58.0
# 3940  2011-01-31            6.49           0.00      76.0      55.0
# 3941  2011-02-01           18.12           0.14      71.0      27.0
# ...          ...             ...            ...       ...       ...
# 5902  2016-06-15            8.05           0.00      95.0      79.0
# 5903  2016-06-16            6.71           0.00      95.0      78.0
# 5904  2016-06-17            5.37           0.00      96.0      77.0
# 5905  2016-06-18            4.92           0.45      97.0      74.0
# 5906  2016-06-19            4.03           0.44      91.0      75.0
#
#       week_year day_of_week  week_day_num  month  year  day_number  \
# 3937      11621      Sunday             2      6  2016        1969
# ...

# %%
# you can observe that there is no nulls in the data
df.isna().sum()
# Out:
# date                 0
# avg_wind_speed       0
# precipitation        0
# max_temp             0
# min_temp             0
# week_year            0
# day_of_week          0
# week_day_num         0
# month                0
# year                 0
# day_number           0
# event_1_name         0
# event_1_type         0
# event_2_name         0
# event_2_type         0
# snap_state_CA        0
# State                0
# snap_state_WI        0
# snap_state_TX        0
# predicted_weather    0
# dtype: int64

# %%
# no duplicate rows
df.duplicated().sum()
# Out:
# 0

# %%
# avg_wind_speed column
plt.boxplot(df['avg_wind_speed'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7e7d9586e550>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7e7d9586d410>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7e7d9586c190>],
#  'medians': [<matplotlib.lines.Line2D at 0x7e7d97b88a90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7e7d97b8bf90>],
#  'means': []}

# %%
# max_temp column
plt.boxplot(df['max_temp'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7e7d97a872d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7e7d97a86410>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7e7d97b35e10>],
#  'medians': [<matplotlib.lines.Line2D at 0x7e7d97a86390>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7e7d97a87d10>],
#  'means': []}

# %%
# min_temp column
plt.boxplot(df['min_temp'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7e7d97bd1a50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7e7d97bd0350>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7e7d958f2750>],
#  'medians': [<matplotlib.lines.Line2D at 0x7e7d97bd02d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7e7d95838310>],
#  'means': []}

# %%
# precipitation column
plt.boxplot(df['precipitation'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7e7d94ec6710>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7e7d94ec4a10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7e7d94ec7ad0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7e7d98abe090>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7e7d97a566d0>],
#  'means': []}

# %%
df[df['max_temp']>100]
# Out:
#             date  avg_wind_speed  precipitation  max_temp  min_temp  \
# 256   2011-10-12            2.91           0.00     102.0      61.0
# 594   2012-09-14            3.58           0.00     104.0      66.0
# 595   2012-09-15            4.70           0.00     103.0      70.0
# 1201  2014-05-14            7.38           0.00     101.0      64.0
# 1202  2014-05-15            5.14           0.00     101.0      66.0
# 1324  2014-09-14            4.70           0.00     101.0      70.0
# 1684  2015-09-09            5.14           0.02     103.0      77.0
# 1714  2015-10-09            4.47           0.00     105.0      69.0
# 1715  2015-10-10            4.47           0.00     102.0      73.0
# 2491  2012-07-04           10.07           0.00     102.0      81.0
# 2492  2012-07-05            6.93           0.00     103.0      73.0
# 4065  2011-06-05            4.25           0.00     102.0      74.0
# 4066  2011-06-06            4.25           0.00     101.0      77.0
# ...
